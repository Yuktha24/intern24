# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuktha24/intern24/blob/main/Task2(LinearRegression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
train_data=pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vRTK2NvcndgPX41Czu6Ft2Ho_nE-z50BgTqdzwFW0rsJ2nvyNLe2DoIg1COzUbgw80oaRBjfy5-WtFk/pubhtml")
test_data=pd.read_html("https://docs.google.com/spreadsheets/d/e/2PACX-1vRyvZ7lknwiSghK9aen1SaTEYoN3JS40rrGLpcyrsVZy1tB2T4gn6Y3-cdzPUFCPMmmqREWefW3kl4_/pubhtml")
set1=train_data[0]
set1.to_csv('train.csv')
train_data=pd.read_csv("train.csv")
train_data
trains=train_data.drop("Unnamed: 0",axis=1)
trains.columns=trains.iloc[0]
train_data=trains.drop(0)
train_data
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [700 rows x 3 columns]

# %%
set2=test_data[0]
set2.to_csv("test.csv")
test_data=pd.read_csv("test.csv")
test_data
tests=test_data.drop("Unnamed: 0",axis=1)
tests.columns=tests.iloc[0]
test_data=tests.drop(0)
test_data
# Out:
# 0      0   x            y
# 1      1  77  79.77515201
# 2      2  21  23.17727887
# 3      3  22  25.60926156
# 4      4  20  17.85738813
# 5      5  36  41.84986439
# ..   ...  ..          ...
# 296  296  71   68.5458879
# 297  297  46  47.33487629
# 298  298  55  54.09063686
# 299  299  62  63.29717058
# 300  300  47  52.45946688
#
# [300 rows x 3 columns]

# %%
train_dataset=train_data.dropna(subset=['y'])
train_dataset
# Out:
# 0      0   x            y
# 1      1  24  21.54945196
# 2      2  50  47.46446305
# 3      3  15  17.21865634
# 4      4  38  36.58639803
# 5      5  87  87.28898389
# ..   ...  ..          ...
# 696  696  58  58.59500642
# 697  697  93  94.62509374
# 698  698  82  88.60376995
# 699  699  66  63.64868529
# 700  700  97   94.9752655
#
# [699 rows x 3 columns]

# %%
x_train=train_dataset[['x']].astype(float)
y_train=train_dataset[['y']].astype(float)
x_test=test_data[['x']].astype(float)
y_test=test_data[['y']].astype(float)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
yhat=model.predict(x_test)
yhat
# Out:
# array([[76.94327594],
#        [20.90651855],
#        [21.90717494],
#        [19.90586217],
#        [35.91636428],
#        [14.90258026],
#        [61.93343021],
#        [94.95509081],
#        [19.90586217],
#        [ 4.89601644],
#        [ 3.89536006],
#        [18.90520579],
#        [95.95574719],
#        [61.93343021],
#        [35.91636428],
#        [14.90258026],
#        [64.93539936],
#        [13.90192388],
#        [86.94983976],
#        [68.93802488],
#        [88.95115252],
#        [50.92621001],
#        [88.95115252],
#        [26.91045685],
#        [96.95640358],
#        [57.93080468],
#        [78.9445887 ],
#        [20.90651855],
#        [92.95377805],
#        [26.91045685],
#        [98.95771634],
#        [30.91308237],
#        [32.91439514],
#        [79.94524508],
#        [27.91111323],
#        [46.92358448],
#        [52.92752277],
#        [68.93802488],
#        [27.91111323],
#        [32.91439514],
#        [90.95246528],
# ...

# %%
#Array must be 1-dimensional for a DataFrame
y_test=y_test.squeeze()
yhat=yhat.squeeze()

# %%
show=pd.DataFrame({"Test value":y_test, "Predicted Value":yhat})
show
# Out:
#      Test value  Predicted Value
# 1     79.775152        76.943276
# 2     23.177279        20.906519
# 3     25.609262        21.907175
# 4     17.857388        19.905862
# 5     41.849864        35.916364
# ..          ...              ...
# 296   68.545888        70.939338
# 297   47.334876        45.922928
# 298   54.090637        54.928836
# 299   63.297171        61.933430
# 300   52.459467        46.923584
#
# [300 rows x 2 columns]
